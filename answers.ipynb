# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/sampleground/assignment0/blob/master/answers.ipynb)

# %%
# Question 1

# %%
import pandas as pd

# %%
url = "https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2017-10.csv"

# %%
nyc_taxi = pd.read_csv(url)

# %%
#Just check-1

# %%
len(nyc_taxi)
# Out:
# 9768815

# %%
# Question 2

# %%
# Q2 - Display the first 5 rows

# %%
nyc_taxi.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2017-10-01 00:01:50   2017-10-01 00:14:13                1
# 1         1  2017-10-01 00:02:43   2017-10-01 00:08:35                2
# 2         1  2017-10-01 00:12:08   2017-10-01 00:25:49                3
# 3         2  2017-10-01 00:00:25   2017-10-01 00:11:24                1
# 4         2  2017-10-01 00:15:30   2017-10-01 00:25:11                1
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           2.00           1                  N           142           233
# 1           2.30           1                  N           142           166
# 2           2.80           1                  N           151           262
# 3           1.97           1                  N           100           229
# 4           2.17           1                  N           141           142
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %%
# Q2 - A statistical summary

# %%
nyc_taxi.describe()
# Out:
#            VendorID  passenger_count  trip_distance    RatecodeID  \
# count  9.768815e+06     9.768815e+06   9.768815e+06  9.768815e+06
# mean   1.549415e+00     1.617468e+00   2.964095e+00  1.045011e+00
# std    4.975522e-01     1.259104e+00   3.814063e+00  4.748632e-01
# min    1.000000e+00     0.000000e+00   0.000000e+00  1.000000e+00
# 25%    1.000000e+00     1.000000e+00   1.000000e+00  1.000000e+00
# 50%    2.000000e+00     1.000000e+00   1.650000e+00  1.000000e+00
# 75%    2.000000e+00     2.000000e+00   3.070000e+00  1.000000e+00
# max    2.000000e+00     9.000000e+00   1.178600e+03  9.900000e+01
#
#        PULocationID  DOLocationID  payment_type   fare_amount         extra  \
# count  9.768815e+06  9.768815e+06  9.768815e+06  9.768815e+06  9.768815e+06
# mean   1.630937e+02  1.612835e+02  1.328251e+00  1.338078e+01  3.300792e-01
# std    6.624797e+01  7.015271e+01  4.901289e-01  3.078552e+02  4.644125e-01
# ...

# %%
#Just check-2

# %%
type(nyc_taxi)
# Out:
# pandas.core.frame.DataFrame

# %%
# Q2- dtypes of the coulmuns

# %%
nyc_taxi.dtypes
# Out:
# VendorID                   int64
# tpep_pickup_datetime      object
# tpep_dropoff_datetime     object
# passenger_count            int64
# trip_distance            float64
# RatecodeID                 int64
# store_and_fwd_flag        object
# PULocationID               int64
# DOLocationID               int64
# payment_type               int64
# fare_amount              float64
# extra                    float64
# mta_tax                  float64
# tip_amount               float64
# tolls_amount             float64
# improvement_surcharge    float64
# total_amount             float64
# dtype: object

# %%
# Question 3

# %%
# Question 3
# I checked the "trip_distance" and "fare_amount" columns if there any inconsistency values exists or not.
# To find this inconsistency, I checked the zero values in "trip_distance", "fare_amount" columns. 
# If taxi goes in any distance then the fare does not be zero. 
# And as well If taxi does not go any distance then the fare does not get any value different than zero.

# %%
nyc_taxi_new = nyc_taxi.loc[~( ( ( nyc_taxi['trip_distance'] == 0 ) & ( nyc_taxi['fare_amount'] > 0 ) ) | ( ( nyc_taxi['trip_distance'] > 0 ) & ( nyc_taxi['fare_amount'] == 0 ) ) ) ]
nyc_taxi_new
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               1  2017-10-01 00:01:50   2017-10-01 00:14:13                1
# 1               1  2017-10-01 00:02:43   2017-10-01 00:08:35                2
# 2               1  2017-10-01 00:12:08   2017-10-01 00:25:49                3
# 3               2  2017-10-01 00:00:25   2017-10-01 00:11:24                1
# 4               2  2017-10-01 00:15:30   2017-10-01 00:25:11                1
# 5               1  2017-10-01 00:27:42   2017-10-01 00:35:36                1
# 6               1  2017-10-01 00:39:19   2017-10-01 00:50:09                1
# 7               1  2017-10-01 00:53:25   2017-10-01 01:10:02                1
# 8               1  2017-10-01 00:03:22   2017-10-01 00:27:15                1
# 9               1  2017-10-01 00:57:24   2017-10-01 01:14:42                1
# 10              2  2017-10-01 00:12:30   2017-10-01 00:36:25                1
# ...

# %%
# Question 4

# %%
import plotly
import plotly.plotly as py
import plotly.tools as tls

import matplotlib.pyplot as plt
import numpy as np

# %%
#gaussian_numbers = np.random.randn(1000)
#plt.hist(nyc_taxi_new['trip_distance'])
plt.subplot(221)
#plt.plot(x, y)
plt.title("Distance")
plt.xlabel("Value")
plt.ylabel("Frequency")


plt.xticks(range(0, 7))
plt.yticks(range(1, 20))
# Out:
# ([<matplotlib.axis.YTick at 0x7fcf1c5a8630>,
# ...
#  <a list of 19 Text yticklabel objects>)

# %%
import numpy as np
import matplotlib.pyplot as pl

x = np.random.randn(10000)

nbins = 20

#n, bins = np.histogram(x, nbins, density=1)
pdfx = np.zeros(n.size)
pdfy = np.zeros(n.size)
for k in range(n.size):
    pdfx[k] = 0.5*(bins[k]+bins[k+1])
    pdfy[k] = n[k]

pl.plot(pdfx, pdfy)
