# %% [markdown]
# DSF Assignment 3: Group assignment
#
# Allison, Pelin and Anastasia
#
# We will use the data from this competition https://www.drivendata.org/competitions/1/united-nations-millennium-development-goals/.
#
# 1. Load the data from the competition, removing any possible meaningless column.
#
# 2. The "Series Code" column contains codes with segments separated by periods ".". Suppose that the first segment represents some global "category". How many unique categories are?
#
# 3. Write a function that receives a country name and returns a pandas DataFrame indexed by year with all the series as columns. Write another similar function that receives a series name and returns the countries.
#
# 4. Plot the "Alternative and nuclear energy (% of total energy use)" of your three countries in the same plot, as well as a centered, 3 year rolling mean.
#
# 5. Which are the 8 countries with the largest "Electricity production from coal sources (kWh)"? Plot the series for those 8 countries.
#
# 6. Among the countries that had a nonzero "Electricity production from coal sources (kWh)" in each of the last 5 years of the dataset, which are the 8 ones that had the biggest percentual increase in those last 5 years? Plot the series for those 8 countries.
#
# 7. Pick some health or development indicators of your choice. "Is the world doing better or worse?". Discuss, compare different countries and/or continents, correlate with other indexes

# %% [markdown]
# 1. Load the data from the competition, removing any possible meaningless column.

# %%
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt
from datetime import datetime 

# change the max width of pandas rows and columns to display
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
pd.set_option('display.max_colwidth', -1)

# %%
data = pd.read_csv("/Users/allison/Desktop/BTSMBDS/Data Science Foundations/data/TrainingSet.csv")

column_name = list(data.columns)

for i in range(0,len(column_name)):
    if "YR" in column_name[i]:
        column_name[i] = datetime.strptime(str(column_name[i].split(" ", 1)[0]), '%Y').strftime('%Y')
    else:
        column_name[i] = column_name[i]        
#Here we are creating a list of column names in order to remove the unecessary extra letters from the years. 
#We also change the type to datetime. 

data.columns = column_name
data = data.drop(columns=[data.columns[0]])
# Dropped the column which name is "Unnamed: 0"

print(len(data))
data.head(2)
# Out:
# 195402
#    1972  1973  1974  1975  1976  1977  1978  1979  1980  1981  1982  1983  1984  1985  1986  1987  1988  1989  1990  1991  1992  1993  1994  1995  1996  1997  1998  1999  2000  2001  2002  2003  2004  2005  2006      2007 Country Name  Series Code                                                      Series Name
# 0 NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    3.769214  Afghanistan  allsi.bi_q1  (%) Benefits held by 1st 20% population - All Social Insurance
# 1 NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    7.027746  Afghanistan  allsp.bi_q1  (%) Benefits held by 1st 20% population - All Social Protection

# %%
#We now know that there are almost 200,000 rows in this dataset, and 40 datapoints. 
#There are many missing data points in the dataset, especially in the earlier years.

# %% [markdown]
# 2. The "Series Code" column contains codes with segments separated by periods ".". Suppose that the first segment represents some global "category". How many unique categories are?

# %%
#splitting the Series Code column into two: Global Category and Other Category

data[['Global Category','Other Category']] = data.pop('Series Code').str.split('.', n=1, expand=True)

# %%
data['Global Category'].nunique()
# Out:
# 62

# %%
#There are 62 unique categories

# %% [markdown]
# 3. Write a function that receives a country name and returns a pandas DataFrame indexed by year with all the series as columns. Write another similar function that receives a series name and returns the countries.

# %%
def series_in_country(country_name):

    #new dataframe filtered by country, new index set to Series name, and then transposed so that years become index
    data_new = data.loc[data['Country Name'] == country_name].set_index(['Series Name']).T 
    
    #Drop the last three rows from newly transposed dataframe(Country, Global category, Other)
    data_new.drop(data_new.tail(3).index,inplace=True)
# 1972         NaN                                                    NaN                                                NaN                                                  NaN                                                       NaN                                                    NaN                                                 NaN                                                                                              13.4414                            NaN
# 1973         NaN                                                    NaN                                                NaN                                                  NaN                                                       NaN                                                    NaN                                                 NaN                                                                                              14.6032                            NaN
# 1974         NaN                                                    NaN                                                NaN                                                  NaN                                                       NaN                                                    NaN                                                 NaN                                                                                              16.8359                            NaN
# 1975         NaN                                                    NaN                                                NaN                                                  NaN                                                       NaN                                                    NaN                                                 NaN                                                                                              19.3716                            NaN
# 1976         NaN                                                    NaN                                                NaN                                                  NaN                                                       NaN                                                    NaN                                                 NaN                                                                                              21.5639                            NaN
#
# [5 rows x 841 columns]

# %%
def countries_in_series(series_name):
     
    x = data.loc[data['Series Name'] == series_name, 'Country Name']
    #return  list(x), len(list(x))
    return  x
countries_in_series('Achieve universal primary education')
# Out:
# 12        Afghanistan
# 895       Albania
# 2100      Algeria
# 3643      Angola
# 4712      Antigua and Barbuda
# 5387      Argentina
# 6565      Armenia
# 7748      Aruba
# 8248      Australia
# 9089      Austria
# 9951      Azerbaijan
# 11173     Bahamas, The
# 11945     Bahrain
# 12806     Bangladesh
# 14040     Barbados
# 14842     Belarus
# 15953     Belgium
# 16823     Belize
# 17917     Benin
# 19072     Bermuda
# 19496     Bhutan
# 20547     Bolivia
# 22896     Botswana
# 25252     Brunei Darussalam
# 26023     Bulgaria
# 27208     Burkina Faso
# 28335     Burundi
# 29445     Cabo Verde
# 30441     Cambodia
# 31653     Cameroon
# 32854     Canada
# 33702     Cayman Islands
# 33955     Central African Republic
# 34895     Chad
# 35964     Chile
# 36953     China
# 38055     Colombia
# 39283     Comoros
# 40170     Congo, Dem. Rep.
# 41290     Congo, Rep.
# 42426     Costa Rica
# 43564     Cote d'Ivoire
# 44711     Croatia
# 45669     Cuba
# 46404     Cyprus
# 48223     Denmark
# 49072     Djibouti
# 50027     Dominica
# 50974     Dominican Republic
# 52180     Ecuador
# 53383     Egypt, Arab Rep.
# 54583     El Salvador
# 55786     Equatorial Guinea
# 56450     Eritrea
# 57401     Estonia
# 58336     Ethiopia
# 59737     Fiji
# 60755     Finland
# 61630     France
# 62498     French Polynesia
# 62893     Gabon
# 63966     Gambia, The
# 65056     Georgia
# 66227     Germany
# 67121     Ghana
# 68345     Greece
# 69395     Grenada
# 70498     Guatemala
# 71688     Guinea
# 72778     Guinea-Bissau
# 73726     Guyana
# 74741     Haiti
# 75779     Honduras
# 76991     Hong Kong SAR, China
# 77798     Hungary
# 78955     Iceland
# 79788     India
# 81024     Indonesia
# 82253     Iran, Islamic Rep.
# 83334     Iraq
# 84111     Ireland
# 85085     Israel
# 85967     Italy
# 86856     Jamaica
# 88017     Japan
# 88896     Jordan
# 90113     Kazakhstan
# 91309     Kenya
# 92530     Kiribati
# 93346     Korea, Rep.
# 94642     Kuwait
# 95533     Kyrgyz Republic
# 96757     Lao PDR
# 97838     Latvia
# 98773     Lebanon
# 99915     Lesotho
# 101024    Liberia
# 102025    Libya
# 102709    Liechtenstein
# 102884    Lithuania
# 103818    Luxembourg
# 104663    Macao SAR, China
# 105329    Macedonia, FYR
# 106515    Madagascar
# 107686    Malawi
# 108768    Malaysia
# 109941    Maldives
# 110959    Mali
# 112084    Malta
# 112944    Marshall Islands
# 113289    Mauritania
# 114251    Mauritius
# 115297    Mexico
# 116892    Moldova
# 118300    Mongolia
# 119530    Montenegro
# 120518    Morocco
# 121751    Mozambique
# 122899    Myanmar
# 123790    Namibia
# 124770    Nepal
# 125957    Netherlands
# 127245    New Zealand
# 128116    Nicaragua
# 129318    Niger
# 130381    Nigeria
# 131623    Norway
# 132491    Oman
# 133384    Pakistan
# 134948    Panama
# 136150    Papua New Guinea
# 137169    Paraguay
# 138368    Peru
# 139602    Philippines
# 140842    Poland
# 141765    Portugal
# 143054    Qatar
# 143781    Romania
# 144989    Russian Federation
# 145941    Rwanda
# 147069    Samoa
# 148153    Sao Tome and Principe
# 149066    Saudi Arabia
# 149924    Senegal
# 151117    Serbia
# 152259    Seychelles
# 153114    Sierra Leone
# 155980    Slovenia
# 156912    Solomon Islands
# 157817    Somalia
# 158519    South Africa
# 159816    Spain
# 160718    Sri Lanka
# 161946    St. Kitts and Nevis
# 162600    St. Lucia
# 163595    St. Vincent and the Grenadines
# 165621    Suriname
# 166409    Swaziland
# 167438    Sweden
# 168313    Switzerland
# 169171    Syrian Arab Republic
# 170328    Tajikistan
# 171492    Tanzania
# 172692    Thailand
# 174542    Togo
# 175691    Tonga
# 176579    Trinidad and Tobago
# 177536    Tunisia
# 178696    Turkey
# 180662    Turks and Caicos Islands
# 181133    Uganda
# 182320    Ukraine
# 183485    United Arab Emirates
# 184239    United Kingdom
# 185089    United States
# 185947    Uruguay
# 186923    Uzbekistan
# 187855    Vanuatu
# 188766    Venezuela, RB
# 189955    Vietnam
# 191251    West Bank and Gaza
# 191981    Yemen, Rep.
# 193101    Zambia
# 194308    Zimbabwe
# Name: Country Name, dtype: object

# %% [markdown]
# 4. Plot the "Alternative and nuclear energy (% of total energy use)" of your three countries in the same plot, as well as a centered, 3 year rolling mean.

# %%
#Note that there is no data for Russian Federation (Anastasia), so we are using Australia (Allison), Turkey (Pelin), and Spain

#Created new dataframe filtered by Alternative and nuclear energy series name, and including only data for our countries, and then transposing so the countries are the column titles
our_countries = data.loc[((data['Country Name'] == 'Australia')|(data['Country Name'] == 'Turkey')|(data['Country Name'] == 'Spain')) & (data['Series Name']=='Alternative and nuclear energy (% of total energy use)')].set_index(['Country Name']).T
our_countries.index.name = 'Year'

#Drop the last four rows from newly transposed dataframe(Country, Global category, Other, Series Name)
our_countries.drop(our_countries.tail(3).index,inplace=True)

our_countries.head()
# Out:
# Country Name Australia    Spain   Turkey
# Year
# 1972          1.87181   9.56525  1.42012
# 1973          1.71997   8.12863  1.1181
# 1974          1.93077   8.07096  1.34412
# 1975          2.09709   7.31891  2.10579
# 1976          2.10287   6.10673  2.67164

# %%
plt.figure(figsize=(15,8))
plt.ylabel('Percentange of total energy use')
plt.title('Alternative and nuclear energy usage in Australia, Turkey and Spain')
 
list_a = list(our_countries.columns.values)
list_b = list(our_countries.columns.values+" rolling")
list_a.extend(list_b)
 
plt.plot(our_countries)
plt.plot(our_countries.rolling(3, center = True).mean())
 
plt.legend(list_a, loc='upper left')
 
plt.xticks(rotation="vertical");

# %% [markdown]
# 5. Which are the 8 countries with the largest "Electricity production from coal sources (kWh)"? Plot the series for those 8 countries.

# %%
#locate the data for the electricity production series name, and remove the extra columns
largest_8 = data.loc[data['Series Name'] == 'Electricity production from coal sources (kWh)'].drop(columns=['Series Name', 'Global Category', 'Other Category'])

#create new column that calculates the average electricity production across all years in the dataframe
largest_8['mean'] = largest_8.mean(1)

#filter dataframe to the 8 countries with the largest mean, set index as Country Name and transpose
largest_8 = largest_8.nlargest(8, columns='mean', keep='first').set_index(['Country Name']).T
largest_8.index.name = 'Year'

#Drop the mean row from newly transposed dataframe
largest_8.drop(largest_8.tail(1).index,inplace=True)
    
largest_8.head()

#We have chosen the mean for our calculations because we feel it is the most accurate measure of electricity production overall. 
#We considered using max values or the sum of all years, but due to missing data, mean seemed the most appropriate.
# Out:
# Country Name  United States         China       Germany         India  United Kingdom  Russian Federation  South Africa         Japan
# Year
# 1972          8.249700e+11   9.775300e+10  2.503480e+11  3.668100e+10  1.452410e+11   NaN                  5.868400e+10  4.160000e+10
# 1973          9.073600e+11   9.771300e+10  2.583160e+11  3.595800e+10  1.746090e+11   NaN                  6.340500e+10  3.730000e+10
# 1974          8.646820e+11   9.684500e+10  2.624910e+11  4.103900e+10  1.488310e+11   NaN                  6.851000e+10  3.976100e+10
# 1975          8.908520e+11   1.106650e+11  2.428290e+11  4.411100e+10  1.694680e+11   NaN                  7.377400e+10  4.231700e+10
# 1976          9.871130e+11   1.043600e+11  2.784880e+11  5.177500e+10  1.798670e+11   NaN                  7.745300e+10  4.377000e+10

# %%
plt.figure(figsize=(15,8))
plt.ylabel('Electricity production from coal sources (kWh)')
plt.title('Electricity production from coal sources (kWh) - Top 8 countries')
 
list_a = list(largest_8.columns.values)
plt.plot(largest_8)
plt.legend(list_a, loc='upper left')
plt.xticks(rotation="vertical");

# %%
#NEED TO DO XTICKS!!

#The above 8 countries have the highest average electricity production from coal over the 35 years of data. 
#We can see that China has had a rapid increase in output in the recent decades.

# %% [markdown]
# 6. Among the countries that had a nonzero "Electricity production from coal sources (kWh)" in each of the last 5 years of the dataset, which are the 8 ones that had the biggest percentual increase in those last 5 years? Plot the series for those 8 countries.

# %%
#locate the data for the electricity production series name, and remove the extra columns
df_percent = data.loc[data['Series Name']== "Electricity production from coal sources (kWh)"].drop(columns=['Series Name', 'Global Category', 'Other Category']).set_index(['Country Name']).T
df_percent.index.name = 'Year'

#Filter to only non-zero columns
df_percent = df_percent.loc[:, (df_percent != 0).all(axis=0)]

#Create new row that calculates percent growth over last 5 years
# 1993          2.849000e+09  1.166000e+09  6.370000e+08  6.180270e+11  2.376100e+10  1.350400e+10 NaN            3.129100e+10
# 1994          4.693000e+09  2.312000e+09  1.071000e+09  6.955320e+11  2.823500e+10  1.413100e+10 NaN            4.195700e+10
# 1995          6.391000e+09  1.879000e+09  2.023000e+09  7.444770e+11  2.804700e+10  1.478000e+10 NaN            4.931200e+10
# 1996          9.499000e+09  1.878000e+09  2.376000e+09  8.240090e+11  3.041300e+10  1.770800e+10 NaN            5.740000e+10
# 1997          9.374000e+09  1.789000e+09  3.325000e+09  8.685730e+11  3.386000e+10  1.915200e+10 NaN            6.929500e+10
# 1998          1.134200e+10  1.704000e+09  3.480000e+09  8.845120e+11  3.568800e+10  1.664400e+10 NaN            8.032200e+10
# 1999          1.277000e+10  1.973000e+09  2.915000e+09  9.643800e+11  3.703100e+10  1.638400e+10 NaN            8.453100e+10
# 2000          8.467000e+09  1.754000e+09  3.135000e+09  1.062144e+12  3.818700e+10  1.777300e+10  2.886000e+09  1.113950e+11
# 2001          4.837000e+09  1.349000e+09  3.218000e+09  1.131196e+12  3.841600e+10  1.986800e+10  3.664000e+09  1.234270e+11
# 2002          5.052000e+09  8.060000e+08  4.878000e+09  1.284893e+12  3.214900e+10  1.883700e+10  3.639000e+09  1.338380e+11
# 2003          4.878000e+09  9.300000e+08  7.237000e+09  1.518701e+12  3.225200e+10  1.936900e+10  3.552000e+09  1.342220e+11
# 2004          7.718000e+09  1.670000e+09  7.173000e+09  1.717470e+12  3.444800e+10  2.060500e+10  3.943000e+09  1.422630e+11
# 2005          7.212000e+09  2.172000e+09  1.217300e+10  1.971772e+12  4.319200e+10  2.052200e+10  4.319000e+09  1.487910e+11
# 2006          1.059900e+10  1.986000e+09  1.411200e+10  2.301896e+12  4.665000e+10  2.530900e+10  4.304000e+09  1.529140e+11
# 2007          1.325900e+10  2.328000e+09  1.461800e+10  2.659622e+12  5.343100e+10  3.076800e+10  4.710000e+09  1.707040e+11

# %%
plt.figure(figsize=(15,8))
plt.ylabel('Electricity production from coal sources (kWh) - Percentage increase 2003 to 2007')
plt.title('Electricity production from coal sources (kWh) - Top 8 countries based on percentage increase')

list_a = list(df_percent.columns.values)
plt.plot(df_percent)
plt.legend(list_a, loc='upper left')
plt.xticks(rotation="vertical");

# %%
#China has a massive percentage increase in comparison to the other countries in the top 8.

# %% [markdown]
# 7. Pick some health or development indicators of your choice. "Is the world doing better or worse?". Discuss, compare different countries and/or continents, correlate with other indexes.

# %% [markdown]
# Six variables were chosen for analysis:
# 1. Adolescent fertility rate (births per 1000 women aged 15-19) #health goal
# 2. Fertility rate, total(births per woman) #health goal
# 3. Life expectancy at birth, total (years) #health goal
# 4. Population aged 65 and above (% of total) #development goal
# 5. Rural population #development goal
# 6. Urban population #development goal
#
# These variables were chosen because:
# - We conducted an analysis of datapoints/missing value per indicator and filtered to those with low missing fata
# - We selected the indicators that were particularly interesting to us as a team of women
# - We cross-checked the indicators with the human development indicators to ensure we were considering important variables.
#
# We understand that this selection does not necessarily provide a holistic view on whether the world is better of or not. However, for the purpose of this analysis we consider these values only.

# %%
def series_top(series_name):
    
    new = data.loc[data['Series Name'] == series_name].drop(columns=['Series Name', 'Global Category', 'Other Category'])
    new['mean'] = new.mean(1)
    new = new.nlargest(8, columns='mean', keep='first').set_index(['Country Name']).T
    new.index.name = 'Year'
    new.drop(new.tail(1).index,inplace=True)
    plt.figure(figsize = (15, 8))
    plt.title(series_name)
    plt.ylabel(series_name)
    plt.xlabel('Year')
    plt.plot(new)
    plt.legend(list(new.columns.values))
    plt.xticks(rotation='vertical');

# %%
def series_bot(series_name):
    
    new = data.loc[data['Series Name'] == series_name].drop(columns=['Series Name', 'Global Category', 'Other Category'])
    new['mean'] = new.mean(1)
    new = new.nsmallest(8, columns='mean', keep='first').set_index(['Country Name']).T
    new.index.name = 'Year'
    new.drop(new.tail(1).index,inplace=True)
    plt.figure(figsize = (15, 8))
    plt.title(series_name)
    plt.ylabel(series_name)
    plt.xlabel('Year')
    plt.plot(new)
    plt.legend(list(new.columns.values))
    plt.xticks(rotation='vertical');

# %%
import geonamescache

gc = geonamescache.GeonamesCache()
countries = gc.get_countries_by_names()

country_continent = pd.DataFrame(pd.DataFrame.from_dict(countries, orient='index', columns=["continentcode"]))
country_continent.index.name = "Country"
country_continent
# Out:
#                                              continentcode
# Country
# Afghanistan                                   AS
# Aland Islands                                 EU
# Albania                                       EU
# Algeria                                       AF
# American Samoa                                OC
# Andorra                                       EU
# Angola                                        AF
# Anguilla                                      NA
# Antarctica                                    AN
# Antigua and Barbuda                           NA
# Argentina                                     SA
# Armenia                                       AS
# Aruba                                         NA
# Australia                                     OC
# Austria                                       EU
# Azerbaijan                                    AS
# Bahamas                                       NA
# Bahrain                                       AS
# Bangladesh                                    AS
# Barbados                                      NA
# Belarus                                       EU
# Belgium                                       EU
# Belize                                        NA
# Benin                                         AF
# Bermuda                                       NA
# Bhutan                                        AS
# Bolivia                                       SA
# Bonaire, Saint Eustatius and Saba             NA
# Bosnia and Herzegovina                        EU
# Botswana                                      AF
# Bouvet Island                                 AN
# Brazil                                        SA
# British Indian Ocean Territory                AS
# British Virgin Islands                        NA
# Brunei                                        AS
# Bulgaria                                      EU
# Burkina Faso                                  AF
# Burundi                                       AF
# Cambodia                                      AS
# Cameroon                                      AF
# Canada                                        NA
# Cape Verde                                    AF
# Cayman Islands                                NA
# Central African Republic                      AF
# Chad                                          AF
# Chile                                         SA
# China                                         AS
# Christmas Island                              OC
# Cocos Islands                                 AS
# Colombia                                      SA
# Comoros                                       AF
# Cook Islands                                  OC
# Costa Rica                                    NA
# Croatia                                       EU
# Cuba                                          NA
# Curacao                                       NA
# Cyprus                                        EU
# Czechia                                       EU
# Democratic Republic of the Congo              AF
# Denmark                                       EU
# Djibouti                                      AF
# Dominica                                      NA
# Dominican Republic                            NA
# Ecuador                                       SA
# Egypt                                         AF
# El Salvador                                   NA
# Equatorial Guinea                             AF
# Eritrea                                       AF
# Estonia                                       EU
# Ethiopia                                      AF
# Falkland Islands                              SA
# Faroe Islands                                 EU
# Fiji                                          OC
# Finland                                       EU
# France                                        EU
# French Guiana                                 SA
# French Polynesia                              OC
# French Southern Territories                   AN
# Gabon                                         AF
# Gambia                                        AF
# Georgia                                       AS
# Germany                                       EU
# Ghana                                         AF
# Gibraltar                                     EU
# Greece                                        EU
# Greenland                                     NA
# Grenada                                       NA
# Guadeloupe                                    NA
# Guam                                          OC
# Guatemala                                     NA
# Guernsey                                      EU
# Guinea                                        AF
# Guinea-Bissau                                 AF
# Guyana                                        SA
# Haiti                                         NA
# Heard Island and McDonald Islands             AN
# Honduras                                      NA
# Hong Kong                                     AS
# Hungary                                       EU
# Iceland                                       EU
# India                                         AS
# Indonesia                                     AS
# Iran                                          AS
# Iraq                                          AS
# Ireland                                       EU
# Isle of Man                                   EU
# Israel                                        AS
# Italy                                         EU
# Ivory Coast                                   AF
# Jamaica                                       NA
# Japan                                         AS
# Jersey                                        EU
# Jordan                                        AS
# Kazakhstan                                    AS
# Kenya                                         AF
# Kiribati                                      OC
# Kosovo                                        EU
# Kuwait                                        AS
# Kyrgyzstan                                    AS
# Laos                                          AS
# Latvia                                        EU
# Lebanon                                       AS
# Lesotho                                       AF
# Liberia                                       AF
# Libya                                         AF
# Liechtenstein                                 EU
# Lithuania                                     EU
# Luxembourg                                    EU
# Macao                                         AS
# Macedonia                                     EU
# Madagascar                                    AF
# Malawi                                        AF
# Malaysia                                      AS
# Maldives                                      AS
# Mali                                          AF
# Malta                                         EU
# Marshall Islands                              OC
# Martinique                                    NA
# Mauritania                                    AF
# Mauritius                                     AF
# Mayotte                                       AF
# Mexico                                        NA
# Micronesia                                    OC
# Moldova                                       EU
# Monaco                                        EU
# Mongolia                                      AS
# Montenegro                                    EU
# Montserrat                                    NA
# Morocco                                       AF
# Mozambique                                    AF
# Myanmar                                       AS
# Namibia                                       AF
# Nauru                                         OC
# Nepal                                         AS
# Netherlands                                   EU
# Netherlands Antilles                          NA
# New Caledonia                                 OC
# New Zealand                                   OC
# Nicaragua                                     NA
# Niger                                         AF
# Nigeria                                       AF
# Niue                                          OC
# Norfolk Island                                OC
# North Korea                                   AS
# Northern Mariana Islands                      OC
# Norway                                        EU
# Oman                                          AS
# Pakistan                                      AS
# Palau                                         OC
# Palestinian Territory                         AS
# Panama                                        NA
# Papua New Guinea                              OC
# Paraguay                                      SA
# Peru                                          SA
# Philippines                                   AS
# Pitcairn                                      OC
# Poland                                        EU
# Portugal                                      EU
# Puerto Rico                                   NA
# Qatar                                         AS
# Republic of the Congo                         AF
# Reunion                                       AF
# Romania                                       EU
# Russia                                        EU
# Rwanda                                        AF
# Saint Barthelemy                              NA
# Saint Helena                                  AF
# Saint Kitts and Nevis                         NA
# Saint Lucia                                   NA
# Saint Martin                                  NA
# Saint Pierre and Miquelon                     NA
# Saint Vincent and the Grenadines              NA
# Samoa                                         OC
# San Marino                                    EU
# Sao Tome and Principe                         AF
# Saudi Arabia                                  AS
# Senegal                                       AF
# Serbia                                        EU
# Serbia and Montenegro                         EU
# Seychelles                                    AF
# Sierra Leone                                  AF
# Singapore                                     AS
# Sint Maarten                                  NA
# Slovakia                                      EU
# Slovenia                                      EU
# Solomon Islands                               OC
# Somalia                                       AF
# South Africa                                  AF
# South Georgia and the South Sandwich Islands  AN
# South Korea                                   AS
# South Sudan                                   AF
# Spain                                         EU
# Sri Lanka                                     AS
# Sudan                                         AF
# Suriname                                      SA
# Svalbard and Jan Mayen                        EU
# Swaziland                                     AF
# Sweden                                        EU
# Switzerland                                   EU
# Syria                                         AS
# Taiwan                                        AS
# Tajikistan                                    AS
# Tanzania                                      AF
# Thailand                                      AS
# Timor Leste                                   OC
# Togo                                          AF
# Tokelau                                       OC
# Tonga                                         OC
# Trinidad and Tobago                           NA
# Tunisia                                       AF
# Turkey                                        AS
# Turkmenistan                                  AS
# Turks and Caicos Islands                      NA
# Tuvalu                                        OC
# U.S. Virgin Islands                           NA
# Uganda                                        AF
# Ukraine                                       EU
# United Arab Emirates                          AS
# United Kingdom                                EU
# United States                                 NA
# United States Minor Outlying Islands          OC
# Uruguay                                       SA
# Uzbekistan                                    AS
# Vanuatu                                       OC
# Vatican                                       EU
# Venezuela                                     SA
# Vietnam                                       AS
# Wallis and Futuna                             OC
# Western Sahara                                AF
# Yemen                                         AS
# Zambia                                        AF
# Zimbabwe                                      AF

# %%
h1 = "Adolescent fertility rate (births per 1,000 women ages 15-19)"
d1 = "Rural population"#"Secondary education, duration (years)"

h2 = "Fertility rate, total (births per woman)"
d2 = "Population ages 65 and above (% of total)"

h3 = "Life expectancy at birth, total (years)"
d3 = "Urban population"#"Primary education, duration (years)"

countries_q7 = set(countries_in_series(h1)) & set(countries_in_series(h2)) & set(countries_in_series(h3)) & set(countries_in_series(d1)) & set(countries_in_series(d2)) & set(countries_in_series(d3))

data_q7 = data[((data["Series Name"] == d1) |
                (data["Series Name"] == h1) |
                (data["Series Name"] == d2) |
                (data["Series Name"] == h2) |
                (data["Series Name"] == h3) |
                (data["Series Name"] == d3) )
                ]

data_continent = data_q7.merge(country_continent, left_on='Country Name', right_on='Country', how='left')
data_continent = data_continent.groupby(['Series Name', 'continentcode']).agg('mean').T

#data_continent.index.name = 'Year'
data_continent.head()
#data_continent.groupby(data['continentcode'])
# Out:
# Series Name   Adolescent fertility rate (births per 1,000 women ages 15-19)                                                         Fertility rate, total (births per woman)                                                   Life expectancy at birth, total (years)                                                        Population ages 65 and above (% of total)                                                    Rural population                                                                    Urban population
# continentcode                                                            AF         AS         EU          NA         OC         SA                                       AF        AS        EU        NA        OC        SA                                      AF         AS         EU         NA         OC         SA                                        AF        AS         EU        NA        OC        SA               AF            AS          EU          NA             OC            SA               AF            AS           EU          NA             OC            SA
# FERTILITY RATE (TOTAL)
#
# - This trended very similarly to adolescent fertility rates overall.
# - At a country level, these rates are volatile amongst the best 8 countries.

# %% [markdown]
# LIFE EXPECTANCY AT BIRTH:
#
# - Life expectancy has trended positively, with all contienents improving.
# - All continents have similar rates, except Africa where life expectancy is a good 10-15 years behind the rest of the world. There has been a promising uptick from 2005, however.
# - The top 8 countries in terms of life expectancy are all some of the most developed and wealthiest countries.

# %% [markdown]
# POPULATION AGED 65 AND ABOVE
#
# - Europe outperforms the rest of the world on this metric by a considerable margin, with more than 15% aged over 65 in recent years.
# - Africa is the only continent to not be improving on this metric.
# - Italy and Germany have had a rapid increase in population aged over 65 recent years, suggesting their healthcare system has improved.

# %% [markdown]
# RURAL AND URBAN POPULATION
#
# - Rural population is fairly flat for all continents.
# - Urban population trends steadily upwards for most of the world, but is increasing fastest in Asia. Can resources keep up with this growth?
# - Italy and Germany have had a rapid increase in urban population over recent years.
# - China and India have the highest rural population by a notable margin.
# - China has also had a rapid growth in urban population, indicating growth in the Chinese population overall.

# %%
corr_table = data_q7.merge(country_continent, left_on='Country Name', right_on='Country', how='left').groupby(['Series Name']).agg('mean').T

# %%
corr_0 = corr_table["Adolescent fertility rate (births per 1,000 women ages 15-19)"]
corr_1 = corr_table["Fertility rate, total (births per woman)"]
corr_2 = corr_table["Life expectancy at birth, total (years)"]
corr_3 = corr_table["Population ages 65 and above (% of total)"]
corr_4 = corr_table["Rural population"]
corr_5 = corr_table["Urban population"]
data_heat = pd.DataFrame(np.corrcoef(corr_0, (corr_1, corr_2, corr_3, corr_4, corr_5)))
data_heat
# Out:
#           0         1         2         3         4         5
# 0  1.000000  0.998011 -0.988092 -0.979689 -0.983071 -0.998575
# 1  0.998011  1.000000 -0.986170 -0.975869 -0.988314 -0.995151
# 2 -0.988092 -0.986170  1.000000  0.945927  0.991530  0.983152
# 3 -0.979689 -0.975869  0.945927  1.000000  0.934522  0.985840
# 4 -0.983071 -0.988314  0.991530  0.934522  1.000000  0.974603
# 5 -0.998575 -0.995151  0.983152  0.985840  0.974603  1.000000

# %%
import seaborn as sns; 
sns.set()
uniform_data = data_heat#np.random.rand(10, 12)
ax = sns.heatmap(uniform_data, vmin=-1, vmax=1)

# %% [markdown]
# CORRELATIONS
#
# The indicators that we have selected are highly correlated, either negatively or positively.
#
# For example, fertility rates are highly positively correlated with eachother, but negatively correlated with the other variables. Ie. as fertility rates drop, life expectancy increases.

# %% [markdown]
# ANALYSIS
#
# From the above data, we can see that fertility rates are dropping, population is aging, and people are increasingly living in urban centers. Independently, the trends in these metrics are promising. However, when taken together these trends reveal a concerning movement towards an aging population and dense urban centers.
#
# Next steps in this analysis would be:
#
# - To analyse the environmental trends (ie. pollution, temperature, resource depletion) to see how the population changes are impacting the globe.
# - To analyse economic trends (ie. GDP). How is population growth impacting wealth?
# - Consider indicators at a country level. A lot of detail and insights is lost by rolling data to a continent level (ie. Japan and Cambodia are in the same continent).
# - Spend more time with the data!
